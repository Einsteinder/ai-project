# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
import pickle

# %%
from weighted_model import Model
from training import Trainer

# %% [markdown]
# ## Initial Variables

# %%
exp_name = '1004'
summary_path = 'summary/' + exp_name
data_path = 'data.p'

# %%
sess= tf.Session()

# %% [markdown]
# ## Loading data

# %%
with open(data_path, 'r') as fin:
    data_info = pickle.load(fin)

# %%
X = data_info['X']
y = data_info['y']
split = data_info['split_info']

# %%
#model Parameters
batch_size = 10000

# %%
X_train = X[np.where(split == 'train')[0]][batch_size:,:]
y_train = y[np.where(split == 'train')[0]][batch_size:].reshape([-1,1])

X_valid = X[np.where(split == 'train')[0]][:batch_size, :]
y_valid = y[np.where(split == 'train')[0]][:batch_size].reshape([-1,1])


X_test = X[np.where(split == 'test')[0]]
y_test = y[np.where(split == 'test')[0]].reshape([-1,1])

# %%
y_train = 1 - y_train
y_valid = 1 - y_valid
y_test = 1 - y_test

# %%
(y_train==0).sum() / (y_train==1).sum()
# Out:
# 54

# %%
#model Parameters
n_variables = X_train.shape[1]
learning_rate = 0.001

convolution_levels = 3
weights_shape = [[n_variables, 256],
                [256, 512],
                [512, 1]]
bias_shape = [256, 512, 1]
positive_weight = 54

# %%
model = Model(n_variables = n_variables, learning_rate = learning_rate)

# %%
model.build_net(learning_rate = learning_rate,
                convolution_levels = convolution_levels, 
                     weights_shape = weights_shape,
                     bias_shape = bias_shape,
                positive_weight = positive_weight)

# %%
trainer = Trainer(model = model,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    X_train = X_train,
                    y_train = y_train,
                    X_valid = X_valid,
                    y_valid = y_valid,)

# %%
trainer.train(max_iter = 100,
              train_eval_step = 1,
              validation_eval_step = 1,
              display_step = 1)
# Out:
# Minibatch Loss = 1.367647
# Training accuracy: 0.5522
# prec: 0.021409455843 rec: 0.516129032258 f1: 0.041113490364
# Validation accuracy: 0.5178
# prec: 0.0207210940738 rec: 0.510204081633 f1: 0.0398247710076
# Minibatch Loss = 1.212710
# Training accuracy: 0.9862
# prec: 0.573825503356 rec: 0.93956043956 f1: 0.7125
# Validation accuracy: 0.9858
# prec: 0.586538461538 rec: 0.933673469388 f1: 0.720472440945
# Minibatch Loss = 1.095622
# Training accuracy: 0.984
# prec: 0.535294117647 rec: 0.989130434783 f1: 0.69465648855
# Validation accuracy: 0.9835
# prec: 0.542936288089 rec: 1.0 f1: 0.703770197487
# Minibatch Loss = 0.920087
# Training accuracy: 0.9784
# prec: 0.433070866142 rec: 1.0 f1: 0.604395604396
# Validation accuracy: 0.9781
# prec: 0.472289156627 rec: 1.0 f1: 0.641571194763
# Minibatch Loss = 0.834616
# Training accuracy: 0.9774
# prec: 0.437810945274 rec: 1.0 f1: 0.608996539792
# Validation accuracy: 0.9775
# prec: 0.465558194774 rec: 1.0 f1: 0.635332252836
# Minibatch Loss = 0.748310
# Training accuracy: 0.9747
# prec: 0.427601809955 rec: 1.0 f1: 0.599049128368
# Validation accuracy: 0.9755
# prec: 0.444444444444 rec: 1.0 f1: 0.615384615385
# Minibatch Loss = 0.644033
# Training accuracy: 0.9686
# prec: 0.38188976378 rec: 1.0 f1: 0.552706552707
# Validation accuracy: 0.9717
# prec: 0.409185803758 rec: 1.0 f1: 0.580740740741
# Minibatch Loss = 0.504101
# Training accuracy: 0.9619
# prec: 0.309782608696 rec: 1.0 f1: 0.473029045643
# Validation accuracy: 0.9661
# prec: 0.366355140187 rec: 1.0 f1: 0.536251709986
# Minibatch Loss = 0.408012
# Training accuracy: 0.9699
# prec: 0.368972746331 rec: 1.0 f1: 0.539050535988
# Validation accuracy: 0.9685
# prec: 0.383561643836 rec: 1.0 f1: 0.554455445545
# Minibatch Loss = 0.312177
# Training accuracy: 0.9702
# prec: 0.343612334802 rec: 1.0 f1: 0.511475409836
# Validation accuracy: 0.9743
# prec: 0.432671081678 rec: 1.0 f1: 0.604006163328
# Minibatch Loss = 0.265847
# Training accuracy: 0.9845
# prec: 0.545454545455 rec: 1.0 f1: 0.705882352941
# Validation accuracy: 0.9851
# prec: 0.568115942029 rec: 1.0 f1: 0.724584103512
# Minibatch Loss = 0.205771
# Training accuracy: 0.9911
# prec: 0.667910447761 rec: 1.0 f1: 0.800894854586
# Validation accuracy: 0.9926
# prec: 0.725925925926 rec: 1.0 f1: 0.841201716738
# Minibatch Loss = 0.160394
# Training accuracy: 0.9942
# prec: 0.769841269841 rec: 1.0 f1: 0.869955156951
# Validation accuracy: 0.9957
# prec: 0.820083682008 rec: 1.0 f1: 0.901149425287
# Minibatch Loss = 0.120991
# Training accuracy: 0.995
# prec: 0.797570850202 rec: 1.0 f1: 0.887387387387
# Validation accuracy: 0.9962
# prec: 0.837606837607 rec: 1.0 f1: 0.911627906977
# Minibatch Loss = 0.080934
# Training accuracy: 0.995
# prec: 0.769585253456 rec: 1.0 f1: 0.869791666667
# Validation accuracy: 0.9968
# prec: 0.859649122807 rec: 1.0 f1: 0.924528301887
# Minibatch Loss = 0.061678
# Training accuracy: 0.996981457525
# prec: 0.855172413793 rec: 1.0 f1: 0.921933085502
# Validation accuracy: 0.998
# prec: 0.907407407407 rec: 1.0 f1: 0.95145631068
# Minibatch Loss = 0.043041
# Training accuracy: 0.9984
# prec: 0.92039800995 rec: 1.0 f1: 0.958549222798
# Validation accuracy: 0.9987
# prec: 0.937799043062 rec: 1.0 f1: 0.967901234568
# Minibatch Loss = 0.031968
# Training accuracy: 0.9998
# prec: 0.989949748744 rec: 1.0 f1: 0.994949494949
# Validation accuracy: 0.9994
# prec: 0.970297029703 rec: 1.0 f1: 0.984924623116
# Minibatch Loss = 0.022133
# Training accuracy: 0.9999
# prec: 0.994871794872 rec: 1.0 f1: 0.997429305913
# Validation accuracy: 0.9998
# prec: 0.989898989899 rec: 1.0 f1: 0.994923857868
# Minibatch Loss = 0.016231
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 0.9999
# prec: 0.994923857868 rec: 1.0 f1: 0.997455470738
# Minibatch Loss = 0.010706
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.008066
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.005312
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.003876
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002794
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002443
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002143
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001248
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000787
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000574
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000646
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000390
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000325
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000291
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000235
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000197
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000160
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000164
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000138
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000117
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000106
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000147
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000096
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000167
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000085
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000080
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000074
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000067
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000068
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000062
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000082
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000059
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000056
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000049
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000098
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000051
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000046
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000049
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000042
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000045
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000044
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000044
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000046
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000040
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000041
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000040
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000075
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000040
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000038
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000040
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000037
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000034
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000051
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000035
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000036
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000032
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000035
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000033
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000035
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000033
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000034
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000035
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000032
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000032
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000043
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000029
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000031
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000030
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000030
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000054
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000028
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000054
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000029
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000029
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000028
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0

# %%
trainer.eval_test(X_test, y_test)
# Out:
# Test accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
