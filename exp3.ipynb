# %% [markdown]
# # Shallow networks w/o weighted cross entropy

# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
import pickle

# %%
from model import Model
from training import Trainer

# %% [markdown]
# ## Initial Variables

# %%
exp_name = '1003'
summary_path = 'summary/' + exp_name
data_path = 'data.p'

# %%
sess= tf.Session()

# %% [markdown]
# ## Loading data

# %%
with open(data_path, 'r') as fin:
    data_info = pickle.load(fin)

# %%
X = data_info['X']
y = data_info['y']
split = data_info['split_info']

# %%
#model Parameters
batch_size = 10000

# %%
X_train = X[np.where(split == 'train')[0]][batch_size:,:]
y_train = y[np.where(split == 'train')[0]][batch_size:].reshape([-1,1])

X_valid = X[np.where(split == 'train')[0]][:batch_size, :]
y_valid = y[np.where(split == 'train')[0]][:batch_size].reshape([-1,1])


X_test = X[np.where(split == 'test')[0]]
y_test = y[np.where(split == 'test')[0]].reshape([-1,1])

# %%
y_train = 1 - y_train
y_valid = 1 - y_valid
y_test = 1 - y_test

# %%
#model Parameters
n_variables = X_train.shape[1]
learning_rate = 0.001

convolution_levels = 1
weights_shape = [[n_variables, 1]]
bias_shape = [1]

# %%
model = Model(n_variables = n_variables, learning_rate = learning_rate)

# %%
model.build_net(learning_rate = learning_rate,
                convolution_levels = convolution_levels, 
                     weights_shape = weights_shape,
                     bias_shape = bias_shape)

# %%
trainer = Trainer(model = model,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    X_train = X_train,
                    y_train = y_train,
                    X_valid = X_valid,
                    y_valid = y_valid,)

# %%
trainer.train(max_iter = 100,
              train_eval_step = 1,
              validation_eval_step = 1,
              display_step = 1)
# Out:
# Minibatch Loss = 0.519459
# Training accuracy: 0.9752
# prec: 0.313432835821 rec: 0.212121212121 f1: 0.253012048193
# Validation accuracy: 0.9779
# prec: 0.396694214876 rec: 0.244897959184 f1: 0.302839116719
# Minibatch Loss = 0.513250
# Training accuracy: 0.9807
# prec: 0.317647058824 rec: 0.166666666667 f1: 0.218623481781
# Validation accuracy: 0.979
# prec: 0.428571428571 rec: 0.214285714286 f1: 0.285714285714
# Minibatch Loss = 0.505408
# Training accuracy: 0.9827
# prec: 0.5 rec: 0.190751445087 f1: 0.276150627615
# Validation accuracy: 0.9797
# prec: 0.456790123457 rec: 0.188775510204 f1: 0.26714801444
# Minibatch Loss = 0.499233
# Training accuracy: 0.9803
# prec: 0.490566037736 rec: 0.132653061224 f1: 0.208835341365
# Validation accuracy: 0.9804
# prec: 0.5 rec: 0.168367346939 f1: 0.251908396947
# Minibatch Loss = 0.491151
# Training accuracy: 0.9827
# prec: 0.611111111111 rec: 0.121546961326 f1: 0.202764976959
# Validation accuracy: 0.9814
# prec: 0.613636363636 rec: 0.137755102041 f1: 0.225
# Minibatch Loss = 0.484706
# Training accuracy: 0.9843
# prec: 0.666666666667 rec: 0.10843373494 f1: 0.186528497409
# Validation accuracy: 0.9813
# prec: 0.655172413793 rec: 0.0969387755102 f1: 0.168888888889
# Minibatch Loss = 0.478189
# Training accuracy: 0.9809
# prec: 0.642857142857 rec: 0.0461538461538 f1: 0.0861244019139
# Validation accuracy: 0.9812
# prec: 0.681818181818 rec: 0.0765306122449 f1: 0.137614678899
# Minibatch Loss = 0.471299
# Training accuracy: 0.9822
# prec: 0.823529411765 rec: 0.0740740740741 f1: 0.135922330097
# Validation accuracy: 0.9808
# prec: 0.625 rec: 0.0510204081633 f1: 0.0943396226415
# Minibatch Loss = 0.464616
# Training accuracy: 0.9811
# prec: 0.636363636364 rec: 0.0364583333333 f1: 0.0689655172414
# Validation accuracy: 0.9807
# prec: 0.615384615385 rec: 0.0408163265306 f1: 0.0765550239234
# Minibatch Loss = 0.457653
# Training accuracy: 0.9838
# prec: 0.888888888889 rec: 0.0473372781065 f1: 0.0898876404494
# Validation accuracy: 0.9808
# prec: 0.75 rec: 0.030612244898 f1: 0.0588235294118
# Minibatch Loss = 0.450320
# Training accuracy: 0.9824
# prec: 1.0 rec: 0.0276243093923 f1: 0.0537634408602
# Validation accuracy: 0.9808
# prec: 1.0 rec: 0.0204081632653 f1: 0.04
# Minibatch Loss = 0.445443
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0112994350282 f1: 0.0223463687151
# Validation accuracy: 0.9806
# prec: 1.0 rec: 0.0102040816327 f1: 0.020202020202
# Minibatch Loss = 0.437950
# Training accuracy: 0.9826
# prec: 1.0 rec: 0.0113636363636 f1: 0.0224719101124
# Validation accuracy: 0.9806
# prec: 1.0 rec: 0.0102040816327 f1: 0.020202020202
# Minibatch Loss = 0.432001
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.00574712643678 f1: 0.0114285714286
# Validation accuracy: 0.9806
# prec: 1.0 rec: 0.0102040816327 f1: 0.020202020202
# Minibatch Loss = 0.425892
# Training accuracy: 0.9829
# prec: 0.666666666667 rec: 0.0116279069767 f1: 0.0228571428571
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.420527
# Training accuracy: 0.982176225385
# prec: 1.0 rec: 0.008 f1: 0.015873015873
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.413675
# Training accuracy: 0.9823
# prec: 1.0 rec: 0.00561797752809 f1: 0.0111731843575
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.409718
# Training accuracy: 0.9806
# prec: 1.0 rec: 0.00512820512821 f1: 0.0102040816327
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.403674
# Training accuracy: 0.9812
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.397900
# Training accuracy: 0.9829
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.391458
# Training accuracy: 0.9826
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.385424
# Training accuracy: 0.9834
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9805
# prec: 1.0 rec: 0.00510204081633 f1: 0.010152284264
# Minibatch Loss = 0.380899
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.00568181818182 f1: 0.0112994350282
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.377531
# Training accuracy: 0.9802
# prec: 1.0 rec: 0.00502512562814 f1: 0.01
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.371664
# Training accuracy: 0.9813
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.365111
# Training accuracy: 0.9846
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.362022
# Training accuracy: 0.9798
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.356257
# Training accuracy: 0.982
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.350715
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.346163
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.342125
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.339579
# Training accuracy: 0.981170044559
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.333240
# Training accuracy: 0.9826
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.328997
# Training accuracy: 0.9821
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.326277
# Training accuracy: 0.9798
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.318649
# Training accuracy: 0.984
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.317332
# Training accuracy: 0.9815
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.310732
# Training accuracy: 0.9837
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.308989
# Training accuracy: 0.9819
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.303161
# Training accuracy: 0.984
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.300284
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.297508
# Training accuracy: 0.9814
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.293019
# Training accuracy: 0.9823
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.290150
# Training accuracy: 0.9814
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.287303
# Training accuracy: 0.9809
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.284968
# Training accuracy: 0.9794
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.278736
# Training accuracy: 0.9829
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.276494
# Training accuracy: 0.981313784677
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.271347
# Training accuracy: 0.9844
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.267666
# Training accuracy: 0.9837
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.268717
# Training accuracy: 0.9799
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.263968
# Training accuracy: 0.9815
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.261828
# Training accuracy: 0.9807
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.256887
# Training accuracy: 0.9829
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.255827
# Training accuracy: 0.9812
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.251424
# Training accuracy: 0.9821
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.251866
# Training accuracy: 0.9794
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.245508
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.244274
# Training accuracy: 0.9814
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.240342
# Training accuracy: 0.9832
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.236800
# Training accuracy: 0.9834
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.236915
# Training accuracy: 0.9822
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.233591
# Training accuracy: 0.9822
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.231770
# Training accuracy: 0.980882564324
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.226899
# Training accuracy: 0.9834
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.228592
# Training accuracy: 0.9792
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.226303
# Training accuracy: 0.9799
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.223182
# Training accuracy: 0.9812
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.222230
# Training accuracy: 0.98
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.219629
# Training accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.216235
# Training accuracy: 0.9819
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.213319
# Training accuracy: 0.9821
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.210781
# Training accuracy: 0.9823
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.208076
# Training accuracy: 0.9829
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.204633
# Training accuracy: 0.9847
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.205168
# Training accuracy: 0.9817
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.203472
# Training accuracy: 0.9822
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.198958
# Training accuracy: 0.9844
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.199575
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.196083
# Training accuracy: 0.983326146327
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.194036
# Training accuracy: 0.9839
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.196212
# Training accuracy: 0.9806
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.195892
# Training accuracy: 0.9794
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.194145
# Training accuracy: 0.9793
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.186764
# Training accuracy: 0.9837
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.189088
# Training accuracy: 0.9807
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.187096
# Training accuracy: 0.9816
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.186398
# Training accuracy: 0.9807
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.184598
# Training accuracy: 0.9815
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.180542
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.180134
# Training accuracy: 0.9824
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.175395
# Training accuracy: 0.9841
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.174630
# Training accuracy: 0.9842
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.175385
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.173438
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.173029
# Training accuracy: 0.981888745149
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.170335
# Training accuracy: 0.9826
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.171881
# Training accuracy: 0.9812
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.169666
# Training accuracy: 0.9823
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.167818
# Training accuracy: 0.9821
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0

# %%
trainer.eval_test(X_test, y_test)
# Out:
# Test accuracy: 0.998157561401
# prec: 1.0 rec: 0.0 f1: 0.0
