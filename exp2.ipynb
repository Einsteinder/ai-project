# %% [markdown]
# # Deep network w/o weighted cross entropy

# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
import pickle

# %%
from model import Model
from training import Trainer

# %% [markdown]
# ## Initial Variables

# %%
exp_name = '1002'
summary_path = 'summary/' + exp_name
data_path = 'data.p'

# %%
sess= tf.Session()

# %% [markdown]
# ## Loading data

# %%
with open(data_path, 'r') as fin:
    data_info = pickle.load(fin)

# %%
X = data_info['X']
y = data_info['y']
split = data_info['split_info']

# %%
#model Parameters
batch_size = 10000

# %%
X_train = X[np.where(split == 'train')[0]][batch_size:,:]
y_train = y[np.where(split == 'train')[0]][batch_size:].reshape([-1,1])

X_valid = X[np.where(split == 'train')[0]][:batch_size, :]
y_valid = y[np.where(split == 'train')[0]][:batch_size].reshape([-1,1])


X_test = X[np.where(split == 'test')[0]]
y_test = y[np.where(split == 'test')[0]].reshape([-1,1])

# %%
y_train = 1 - y_train
y_valid = 1 - y_valid
y_test = 1 - y_test

# %%
#model Parameters
n_variables = X_train.shape[1]
learning_rate = 0.001

convolution_levels = 3
weights_shape = [[n_variables, 256],
                [256, 512],
                [512, 1]]
bias_shape = [256, 512, 1]

# %%
model = Model(n_variables = n_variables, learning_rate = learning_rate)

# %%
model.build_net(learning_rate = learning_rate,
                convolution_levels = convolution_levels, 
                     weights_shape = weights_shape,
                     bias_shape = bias_shape)

# %%
trainer = Trainer(model = model,
                    sess = sess,
                    summary_path = summary_path,
                    batch_size = batch_size,
                    global_step = 0,
                    X_train = X_train,
                    y_train = y_train,
                    X_valid = X_valid,
                    y_valid = y_valid,)

# %%
trainer.train(max_iter = 100,
              train_eval_step = 1,
              validation_eval_step = 1,
              display_step = 1)
# Out:
# Minibatch Loss = 0.799694
# Training accuracy: 0.0099
# prec: 0.00787958379634 rec: 0.493670886076 f1: 0.0155115839714
# Validation accuracy: 0.0101
# prec: 0.00841017326983 rec: 0.423469387755 f1: 0.0164927968207
# Minibatch Loss = 0.549646
# Training accuracy: 0.9795
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.365903
# Training accuracy: 0.9832
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.245636
# Training accuracy: 0.9796
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.163648
# Training accuracy: 0.9815
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.115322
# Training accuracy: 0.9828
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.093765
# Training accuracy: 0.9828
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.085640
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.090895
# Training accuracy: 0.9811
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.094337
# Training accuracy: 0.9809
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.088544
# Training accuracy: 0.9827
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.094459
# Training accuracy: 0.9819
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.089683
# Training accuracy: 0.9832
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.104907
# Training accuracy: 0.9799
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.089140
# Training accuracy: 0.9829
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.084192
# Training accuracy: 0.983469886445
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.080671
# Training accuracy: 0.9836
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.085666
# Training accuracy: 0.9817
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.086151
# Training accuracy: 0.9808
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.078642
# Training accuracy: 0.9814
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.068284
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.068500
# Training accuracy: 0.9807
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.060839
# Training accuracy: 0.9812
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.052146
# Training accuracy: 0.9824
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.048621
# Training accuracy: 0.9825
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.045714
# Training accuracy: 0.9814
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.041897
# Training accuracy: 0.9816
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.041904
# Training accuracy: 0.9801
# prec: 1.0 rec: 0.0 f1: 0.0
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.036153
# Training accuracy: 0.9832
# prec: 1.0 rec: 0.00591715976331 f1: 0.0117647058824
# Validation accuracy: 0.9804
# prec: 1.0 rec: 0.0 f1: 0.0
# Minibatch Loss = 0.035792
# Training accuracy: 0.984
# prec: 1.0 rec: 0.0960451977401 f1: 0.175257731959
# Validation accuracy: 0.9824
# prec: 1.0 rec: 0.102040816327 f1: 0.185185185185
# Minibatch Loss = 0.033081
# Training accuracy: 0.9898
# prec: 1.0 rec: 0.324503311258 f1: 0.49
# Validation accuracy: 0.9885
# prec: 1.0 rec: 0.413265306122 f1: 0.584837545126
# Minibatch Loss = 0.033450
# Training accuracy: 0.991088112692
# prec: 1.0 rec: 0.515625 f1: 0.680412371134
# Validation accuracy: 0.9925
# prec: 1.0 rec: 0.617346938776 f1: 0.763406940063
# Minibatch Loss = 0.029362
# Training accuracy: 0.9946
# prec: 1.0 rec: 0.694915254237 f1: 0.82
# Validation accuracy: 0.9948
# prec: 1.0 rec: 0.734693877551 f1: 0.847058823529
# Minibatch Loss = 0.025143
# Training accuracy: 0.9962
# prec: 1.0 rec: 0.781609195402 f1: 0.877419354839
# Validation accuracy: 0.996
# prec: 1.0 rec: 0.795918367347 f1: 0.886363636364
# Minibatch Loss = 0.022219
# Training accuracy: 0.9977
# prec: 1.0 rec: 0.879581151832 f1: 0.935933147632
# Validation accuracy: 0.9967
# prec: 1.0 rec: 0.831632653061 f1: 0.908077994429
# Minibatch Loss = 0.018547
# Training accuracy: 0.997
# prec: 1.0 rec: 0.832402234637 f1: 0.908536585366
# Validation accuracy: 0.997
# prec: 1.0 rec: 0.84693877551 f1: 0.917127071823
# Minibatch Loss = 0.016130
# Training accuracy: 0.9983
# prec: 1.0 rec: 0.912371134021 f1: 0.954177897574
# Validation accuracy: 0.9975
# prec: 1.0 rec: 0.872448979592 f1: 0.931880108992
# Minibatch Loss = 0.013168
# Training accuracy: 0.998
# prec: 1.0 rec: 0.889502762431 f1: 0.941520467836
# Validation accuracy: 0.998
# prec: 1.0 rec: 0.897959183673 f1: 0.94623655914
# Minibatch Loss = 0.010855
# Training accuracy: 0.9986
# prec: 1.0 rec: 0.9125 f1: 0.954248366013
# Validation accuracy: 0.9982
# prec: 1.0 rec: 0.908163265306 f1: 0.951871657754
# Minibatch Loss = 0.010789
# Training accuracy: 0.9986
# prec: 1.0 rec: 0.927835051546 f1: 0.96256684492
# Validation accuracy: 0.9985
# prec: 1.0 rec: 0.923469387755 f1: 0.960212201592
# Minibatch Loss = 0.009145
# Training accuracy: 0.9996
# prec: 1.0 rec: 0.979057591623 f1: 0.989417989418
# Validation accuracy: 0.9988
# prec: 1.0 rec: 0.938775510204 f1: 0.968421052632
# Minibatch Loss = 0.008576
# Training accuracy: 0.9995
# prec: 1.0 rec: 0.975490196078 f1: 0.987593052109
# Validation accuracy: 0.9993
# prec: 1.0 rec: 0.964285714286 f1: 0.981818181818
# Minibatch Loss = 0.006483
# Training accuracy: 0.9997
# prec: 1.0 rec: 0.982558139535 f1: 0.991202346041
# Validation accuracy: 0.9995
# prec: 1.0 rec: 0.974489795918 f1: 0.987080103359
# Minibatch Loss = 0.005918
# Training accuracy: 0.9995
# prec: 1.0 rec: 0.972972972973 f1: 0.986301369863
# Validation accuracy: 0.9996
# prec: 1.0 rec: 0.979591836735 f1: 0.989690721649
# Minibatch Loss = 0.004772
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 0.9999
# prec: 1.0 rec: 0.994897959184 f1: 0.997442455243
# Minibatch Loss = 0.003762
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002804
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002599
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.002293
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001955
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001708
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001465
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001301
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.001047
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000923
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000766
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000801
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000686
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000590
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000494
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000432
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000379
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000368
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000317
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000292
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000264
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000250
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000226
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000206
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000200
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000180
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000178
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000171
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000144
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000162
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000128
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000130
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000121
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000109
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000104
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000097
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000101
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000096
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000090
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000094
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000077
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000070
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000077
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000078
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000070
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000070
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000063
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000075
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000062
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000059
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000062
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000057
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000058
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000052
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Minibatch Loss = 0.000052
# Training accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
# Validation accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0

# %%
trainer.eval_test(X_test, y_test)
# Out:
# Test accuracy: 1.0
# prec: 1.0 rec: 1.0 f1: 1.0
